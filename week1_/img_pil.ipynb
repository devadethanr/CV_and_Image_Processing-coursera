# %%
#concat two images using pillow 

def get_concat_h(img1, img2):
    dst = Image.new('RGB', (img1.width + img2.width), img1.height)
    dst.paste(img1, (0,0))
    dst.paste(img2, (img1.width, 0))
    return dst

# %%
my_img = "resources/lenna.png"

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'd:\\dev\\ed\\masters in data science and business analytics\\project\\CV_and_Image_Processing-coursera\\week1_'

# %%
image_path = os.path.join(cwd, my_img)
image_path
# Out:
# 'd:\\dev\\ed\\masters in data science and business analytics\\project\\CV_and_Image_Processing-coursera\\week1_\\resources/lenna.png'

# %%
#importing image library from pillow
from PIL import Image

# %%
#opening image using open fn
image = Image.open(my_img)
type(image)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
#printing / showing image
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
image.show() #open in picture

# %%
#using matplotlib to show image
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.show()

# %%
#can be also used to load img by entire path
image = Image.open(image_path)

# %%
print(image.size)
# Out:
# (512, 512)

# %%
print(image.mode)#mode of image being opened
# Out:
# RGB

# %%
im = image.load() #loads and expands the image

# %%
x = 0 #check the intensity of the image at the $x$-th column and $y$-th row:
y = 1
im[y,x]
# Out:
# (226, 137, 125)

# %%
#SAVING THE image in jpg format
image.save("resources/lenna.jpg")

# %% [markdown]
# ## Grayscale Images, Quantization and Color Channels
